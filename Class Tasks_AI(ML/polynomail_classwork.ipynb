# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df= pd.read_csv('data.csv')
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
X = df.iloc[:, 1:2]

# %%
X
# Out:
#    Temperature
# 0            0
# 1           20
# 2           40
# 3           60
# 4           80
# 5          100

# %%
X = df.iloc[:, 1:2].values

# %%
X
# Out:
# array([[  0],
#        [ 20],
#        [ 40],
#        [ 60],
#        [ 80],
#        [100]])

# %%
Y = df.iloc[:, 2]

# %%
Y
# Out:
# 0    0.0002
# 1    0.0012
# 2    0.0060
# 3    0.0300
# 4    0.0900
# 5    0.2700
# Name: Pressure, dtype: float64

# %%
Y = df.iloc[:, 2].values

# %%
Y
# Out:
# array([2.0e-04, 1.2e-03, 6.0e-03, 3.0e-02, 9.0e-02, 2.7e-01])

# %%
lin = LinearRegression()

lin.fit(X,Y)
# Out:
# LinearRegression()

# %%
poly = PolynomialFeatures(degree=4)

# %%
poly
# Out:
# PolynomialFeatures(degree=4)

# %%
X_poly = poly.fit_transform(X)

# %%
X_poly
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#        [1.000e+00, 2.000e+01, 4.000e+02, 8.000e+03, 1.600e+05],
#        [1.000e+00, 4.000e+01, 1.600e+03, 6.400e+04, 2.560e+06],
#        [1.000e+00, 6.000e+01, 3.600e+03, 2.160e+05, 1.296e+07],
#        [1.000e+00, 8.000e+01, 6.400e+03, 5.120e+05, 4.096e+07],
#        [1.000e+00, 1.000e+02, 1.000e+04, 1.000e+06, 1.000e+08]])

# %%
poly.fit(X_poly, Y)
# Out:
# PolynomialFeatures(degree=4)

# %%
lin2 = LinearRegression()
lin2.fit(X_poly, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color='blue')

plt.plot(X, lin.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')

plt.show()
# Out:
# C:\Users\STUDENT\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
plt.scatter(X, Y, color='blue')

plt.plot(X, lin2.predict(poly.fit_transform(X)),color='red')
plt.title('Polynomial Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')

plt.show()

# %%
pred = 110.0
predarray = np.array([[pred]])
lin.predict(predarray)
# Out:
# array([0.20675333])

# %%
pred2 = 110.0
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([0.43295877])

# %% [markdown]
# ### finish

# %%
predarray
# Out:
# array([[110.]])

# %%
pred2array
# Out:
# array([[110.]])

# %%
pred2 = 100
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([0.26973889])

# %%
pred = 100
predarray = np.array([[pred]])
lin.predict(predarray)
# Out:
# array([0.18333333])

# %%
pred2 = 0
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([0.00046111])
