# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from word2number import w2n

# %%
df= pd.read_csv('hussain.csv')
df
# Out:
#      Customer_ID  Gender Married  Dependents     Education Self_Employed  \
# 0            569  Female      No           0      Graduate            No
# 1             15    Male     Yes           2      Graduate            No
# 2             95    Male      No           0  Not Graduate            No
# 3            134    Male     Yes           0      Graduate           Yes
# 4            556    Male     Yes           1      Graduate            No
# ..           ...     ...     ...         ...           ...           ...
# 609          480    Male     Yes           2      Graduate            No
# 610          525    Male      No           0      Graduate            No
# 611          551    Male     Yes           2      Graduate           Yes
# 612          552    Male     Yes           1  Not Graduate            No
# 613          606    Male     Yes           0  Not Graduate            No
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         614 non-null    int64
#  1   Gender              614 non-null    object
#  2   Married             614 non-null    object
#  3   Dependents          614 non-null    int64
#  4   Education           614 non-null    object
#  5   Self_Employed       614 non-null    object
#  6   Applicant_Income    614 non-null    int64
#  7   Coapplicant_Income  614 non-null    float64
#  8   Loan_Amount         614 non-null    int64
#  9   Loan_Amount_Term    614 non-null    int64
#  10  Credit_History      614 non-null    int64
#  11  Property_Area       614 non-null    object
#  12  Loan_Status         614 non-null    object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 62.5+ KB

# %%
df.isnull()
# Out:
#      Customer_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0          False   False    False       False      False          False
# 1          False   False    False       False      False          False
# 2          False   False    False       False      False          False
# 3          False   False    False       False      False          False
# 4          False   False    False       False      False          False
# ..           ...     ...      ...         ...        ...            ...
# 609        False   False    False       False      False          False
# 610        False   False    False       False      False          False
# 611        False   False    False       False      False          False
# 612        False   False    False       False      False          False
# 613        False   False    False       False      False          False
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Loan_Amount_Term  \
# ...

# %%
df.isnull().any()
# Out:
# Customer_ID           False
# Gender                False
# Married               False
# Dependents            False
# Education             False
# Self_Employed         False
# Applicant_Income      False
# Coapplicant_Income    False
# Loan_Amount           False
# Loan_Amount_Term      False
# Credit_History        False
# Property_Area         False
# Loan_Status           False
# dtype: bool

# %%
df.isnull().count()
# Out:
# Customer_ID           614
# Gender                614
# Married               614
# Dependents            614
# Education             614
# Self_Employed         614
# Applicant_Income      614
# Coapplicant_Income    614
# Loan_Amount           614
# Loan_Amount_Term      614
# Credit_History        614
# Property_Area         614
# Loan_Status           614
# dtype: int64

# %%
dff=df

# %%
dff.Gender.nunique()
# Out:
# 2

# %%
dff['Gender']=dff['Gender'].map({'Male':0,'Female':1})

# %%
dff['Gender']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 609    0
# 610    0
# 611    0
# 612    0
# 613    0
# Name: Gender, Length: 614, dtype: int64

# %%
loan=df['Loan_Amount']

# %%
df2=dff[['Gender','Loan_Amount']]

# %%
df2
# Out:
#      Gender  Loan_Amount
# 0         1            9
# 1         0           17
# 2         0           25
# 3         0           25
# 4         0           26
# ..      ...          ...
# 609       0           10
# 610       0           15
# 611       0           25
# 612       0           30
# 613       0           25
#
# [614 rows x 2 columns]

# %%
df2.plot(kind='bar',x='Gender',y='Loan_Amount')
# Out:
# <Axes: xlabel='Gender'>

# %%
df2.plot(kind='hist',x='Gender',y='Loan_Amount')
# Out:
# <Axes: ylabel='Frequency'>

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
le=LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
dfle= df    #dff0r lable encoder
dfle.Gender = le.fit_transform(dfle.Gender)
dfle.Married = le.fit_transform(dfle.Married)
dfle
# Out:
#      Customer_ID  Gender  Married  Dependents     Education Self_Employed  \
# 0            569       1        0           0      Graduate            No
# 1             15       0        1           2      Graduate            No
# 2             95       0        0           0  Not Graduate            No
# 3            134       0        1           0      Graduate           Yes
# 4            556       0        1           1      Graduate            No
# ..           ...     ...      ...         ...           ...           ...
# 609          480       0        1           2      Graduate            No
# 610          525       0        0           0      Graduate            No
# 611          551       0        1           2      Graduate           Yes
# 612          552       0        1           1  Not Graduate            No
# 613          606       0        1           0  Not Graduate            No
#
#      Applicant_Income  Coapplicant_Income  Loan_Amount  Loan_Amount_Term  \
# ...

# %%
dfle1=dfle.drop(['Education','Self_Employed','Property_Area','Loan_Status'],axis=1)

# %%
dfle1
# Out:
#      Customer_ID  Gender  Married  Dependents  Applicant_Income  \
# 0            569       1        0           0              2378
# 1             15       0        1           2              1299
# 2             95       0        0           0              3620
# 3            134       0        1           0              3459
# 4            556       0        1           1              5468
# ..           ...     ...      ...         ...               ...
# 609          480       0        1           2              2947
# 610          525       0        0           0              4680
# 611          551       0        1           2              6633
# 612          552       0        1           1              2492
# 613          606       0        1           0              2400
#
#      Coapplicant_Income  Loan_Amount  Loan_Amount_Term  Credit_History
# 0                   0.0            9               360               1
# ...

# %%
x=dfle1[['Customer_ID','Gender','Married','Dependents','Applicant_Income','Coapplicant_Income','Loan_Amount_Term','Credit_History']]

# %%
x
# Out:
#      Customer_ID  Gender  Married  Dependents  Applicant_Income  \
# 0            569       1        0           0              2378
# 1             15       0        1           2              1299
# 2             95       0        0           0              3620
# 3            134       0        1           0              3459
# 4            556       0        1           1              5468
# ..           ...     ...      ...         ...               ...
# 609          480       0        1           2              2947
# 610          525       0        0           0              4680
# 611          551       0        1           2              6633
# 612          552       0        1           1              2492
# 613          606       0        1           0              2400
#
#      Coapplicant_Income  Loan_Amount_Term  Credit_History
# 0                   0.0               360               1
# 1                1086.0               120               1
# ...

# %%
x.values
# Out:
# array([[5.690e+02, 1.000e+00, 0.000e+00, ..., 0.000e+00, 3.600e+02,
#         1.000e+00],
#        [1.500e+01, 0.000e+00, 1.000e+00, ..., 1.086e+03, 1.200e+02,
#         1.000e+00],
#        [9.500e+01, 0.000e+00, 0.000e+00, ..., 0.000e+00, 1.200e+02,
#         1.000e+00],
#        ...,
#        [5.510e+02, 0.000e+00, 1.000e+00, ..., 0.000e+00, 3.600e+02,
#         0.000e+00],
#        [5.520e+02, 0.000e+00, 1.000e+00, ..., 2.375e+03, 3.600e+02,
#         1.000e+00],
#        [6.060e+02, 0.000e+00, 1.000e+00, ..., 3.800e+03, 1.800e+02,
#         1.000e+00]], shape=(614, 8))

# %%
y= dfle.Loan_Amount.values

# %%
y
# Out:
# array([  9,  17,  25,  25,  26,  30,  30,  35,  36,  40,  40,  42,  44,
#         44,  45,  45,  46,  47,  48,  50,  50,  50,  50,  53,  54,  55,
#         55,  55,  55,  56,  56,  58,  59,  60,  60,  60,  60,  61,  62,
#         63,  65,  66,  66,  66,  66,  67,  67,  67,  70,  70,  70,  70,
#         70,  70,  70,  70,  71,  71,  71,  71,  71,  72,  73,  74,  74,
#         74,  75,  75,  75,  76,  76,  78,  80,  80,  80,  80,  80,  80,
#         81,  81,  81,  81,  81,  81,  83,  84,  84,  84,  84,  85,  86,
#         87,  87,  88,  88,  88,  88,  89,  90,  90,  90,  90,  90,  90,
#         93,  93,  93,  94,  94,  94,  94,  95,  95,  95,  95,  95,  95,
#         95,  95,  95,  96,  96,  96,  96,  96,  96,  96,  96,  96,  97,
#         97,  98,  98,  98,  98,  99,  99,  99,  99, 100, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 101, 102,
#        102, 102, 103, 103, 103, 104, 104, 104, 104, 104, 104, 104, 105,
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer([('hussain',OneHotEncoder(),[0])],remainder='passthrough')
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('hussain', OneHotEncoder(), [0])])

# %%
x= ct.fit_transform(x)
x
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3482 stored elements and shape (614, 621)>
